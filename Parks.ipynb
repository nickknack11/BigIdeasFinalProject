# %% [markdown]
# If we run this code below, a dictionary with the neighborhoods as the keys and the number of parks they contain is printed.

# %%
#puts neighborhoods as the key and how many parks they have as the value in a dictionary
neighborhoods_dictionary = {}
for index, rows in df.iterrows():
    if(rows["neighborhood"] in neighborhoods_dictionary):
        neighborhoods_dictionary[rows["neighborhood"]] += 1
    else:
        neighborhoods_dictionary[rows["neighborhood"]] = 1
print(neighborhoods_dictionary)
# Out:
# {'South Side Slopes': 6, 'South Side Flats': 2, 'Lower Lawrenceville': 4, 'Banksville': 2, 'Allentown': 1, 'Brighton Heights': 7, 'Hazelwood': 4, 'Lincoln-Lemington-Belmar': 2, 'Windgap': 1, 'Troy Hill': 3, 'South Oakland': 2, 'Brookline': 6, 'Arlington': 1, 'Mount Washington': 4, 'Crafton Heights': 2, 'East Hills': 1, 'East Liberty': 1, 'Highland Park': 4, 'Squirrel Hill South': 5, 'Upper Lawrenceville': 1, 'Fineview': 1, 'Regent Square': 2, 'Garfield': 1, 'Perry South': 1, 'Perry North': 2, 'Elliott': 2, 'Beechview': 3, 'Morningside': 3, 'Central Lawrenceville': 2, 'Bedford Dwellings': 2, 'Terrace Village': 1, 'Larimer': 1, 'Beltzhoover': 3, 'Greenfield': 2, 'Manchester': 2, 'Allegheny Center': 2, 'Central Oakland': 1, 'Lincoln Place': 1, 'Sheraden': 3, 'Shadyside': 3, 'Spring Garden': 1, 'Oakwood': 1, 'Stanton Heights': 1, 'Carrick': 5, 'Marshall-Shadeland': 1, 'Spring Hill-City View': 2, 'West End': 1, 'Polish Hill': 1, 'Westwood': 2, 'Squirrel Hill North': 1, 'Homewood South': 1
# ...

# %% [markdown]
# If we run this code believe, a bar graph to better represent the data in the dictionary is displayed to the screen.

# %%
import pandas as pd
df = pd.read_csv("NeighborhoodParks.csv")
num_parks = (df["neighborhood"].value_counts())
num_parks.plot(kind = "bar", figsize = (28,12))

# %% [markdown]
# Brighton heights clearly has the highest number of parks with 7 and South side slopes and brookline are a close second with 6 each. Furthermore, Squirell Hill South and Carrick are close behind with 5.  All of these neighborhoods listed have a lot of parks making them more desirable to raise a family in.  Some of the neighborhoods with a lower number of parks were West End, Larimer, and Homewood South with only 1 park each.  Squirell Hill south is a neighborhood that consitently appeared on the better end of our other two metrics, crime and average age of death, and it apperared on the upper end of this metric.  Due to this, we believe that Squirell Hill south is an even better neighborhood to raise a family in in after acquiring the number of parks there.
